# %% [markdown]
# # Intro.
# - KA(West) Test Bed 결과 확인
# - Exp_Util.py로 정리

# %%
# %matplotlib inline
from Exp_Util import *

ap_table = {}

# %%
GT_corr_mat = KA_GT_corr_mat_viz('KAIST_All_Day(West)')

# %% [markdown]
# # K=10, L=5

# %%
exp_dict = {
    'cluster_center' : 10,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-03-21-43',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-03-17-39',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-01-50-04',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-01-53-53',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-20-42-42',
]


table = KAintraExpPlot(exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.519226  0.635891  0.664677        0.700482       0.683535

# %% [markdown]
# # K=5, L=5

# %%
exp_dict = {
    'cluster_center' : 5,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-15-58-55',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-15-54-30',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-14-45-18',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-14-48-11',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-17-22-59',
]

table = KAintraExpPlot(exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.525688  0.519091  0.637338        0.700776       0.686658

# %% [markdown]
# # K=15, L =5

# %%
exp_dict = {
    'cluster_center' : 15,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-19-11-09',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-19-03-38',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-16-10-09',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-16-17-58',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-17-24-48',
]

table = KAintraExpPlot(exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.539805  0.644243  0.680213        0.696188       0.677392

# %%
column_order = ['ORB','BRISK','SURF','Ours (512dim)','Ours (1024dim)']
FinalTable = DataFrame(columns=column_order)
for k,v in zip(ap_table.keys(), ap_table.values()):
    for col in column_order:
        FinalTable.loc[k,col] = v[col].values[0]

FinalTable
# Out:
#             ORB     BRISK      SURF Ours (512dim) Ours (1024dim)
# K5L5   0.525688  0.519091  0.637338      0.686658       0.700776
# K10L5  0.519226  0.635891  0.664677      0.683535       0.700482
# K15L5  0.539805  0.644243  0.680213      0.677392       0.696188
