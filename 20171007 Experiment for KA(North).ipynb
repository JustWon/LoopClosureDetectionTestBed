# %% [markdown]
# # Intro.
# - KA(North) Test Bed 결과 확인
# - Exp_Util.py로 정리

# %%
# %matplotlib inline
from Exp_Util import *

ap_table = {}

# %%
GT_corr_mat = KA_GT_corr_mat_viz('KAIST_All_Day(North)')

# %% [markdown]
# # K=10, L=5

# %%
exp_dict = {
    'cluster_center' : 10,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-14-38-29',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-14-36-33',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-11-07-53',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-10-10-12',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-20-48-15',
]

table = KAintraExpPlot(exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK     SURF  Ours (2048dim)  Ours (512dim)
# 0  0.471773  0.525456  0.58507        0.640201       0.610387

# %% [markdown]
# # K=5, L=5

# %%
exp_dict = {
    'cluster_center' : 5,
    'depth_level' : 5
}
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-15-59-16',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-15-57-38',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-14-47-17',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-15-33-04',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-17-33-24'
]
table = KAintraExpPlot(exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.471154  0.466297  0.552688        0.641341       0.616342

# %% [markdown]
# # K=15, L=5

# %%
exp_dict = {
    'cluster_center' : 15,
    'depth_level' : 5
}
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-19-11-42',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-19-08-43',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-16-15-40',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-18-11-36',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-17-36-44'
]
table = KAintraExpPlot(exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB    BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.479729  0.53334  0.604919        0.638482       0.602475

# %%
column_order = ['ORB','BRISK','SURF','Ours (512dim)','Ours (1024dim)']
FinalTable = DataFrame(columns=column_order)
for k,v in zip(ap_table.keys(), ap_table.values()):
    for col in column_order:
        FinalTable.loc[k,col] = v[col].values[0]

FinalTable
# Out:
#             ORB     BRISK      SURF Ours (512dim) Ours (1024dim)
# K10L5  0.471773  0.525456   0.58507      0.610387       0.640201
# K15L5  0.479729   0.53334  0.604919      0.602475       0.638482
# K5L5   0.471154  0.466297  0.552688      0.616342       0.641341
