# %% [markdown]
# # Intro.
# - New College, Survey final 데이터에 대한 평가
# - Exp_Util.py로 정리

# %%
# %matplotlib inline
from Exp_Util import *

ap_table = {}

# %%
dataset_name = 'NC'
GT_corr_mat = GT_corr_mat_viz(nc_real_corr_list)

# %% [markdown]
# # K=10, L=5

# %%
exp_dict = {
    'cluster_center' : 10,
    'depth_level' : 5
}
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-22-45-59',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-22-40-04',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-22-34-16',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-21-48-21',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-21-08-45',
]

table = intraExpPlot(dataset_name, exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.751711  0.735806  0.763036        0.782901       0.769743

# %% [markdown]
# # K=15, L=5

# %%
exp_dict = {
    'cluster_center' : 15,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-03-00-39-28',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-03-00-30-47',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-03-00-19-11',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-23-18-11',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-21-25-17',
]

table = intraExpPlot(dataset_name, exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB    BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.748066  0.74759  0.770941        0.784822       0.773851

# %% [markdown]
# # K=5, L=5

# %%
exp_dict = {
    'cluster_center' : 5,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-03-00-38-52',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-03-00-27-25',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-03-00-16-03',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-22-52-27',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-21-19-01'
]

table = intraExpPlot(dataset_name, exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.753681  0.682999  0.712838         0.78943        0.77068

# %%
column_order = ['ORB','BRISK','SURF','Ours (512dim)','Ours (1024dim)']
FinalTable = DataFrame(columns=column_order)
for k,v in zip(ap_table.keys(), ap_table.values()):
    for col in column_order:
        FinalTable.loc[k,col] = v[col].values[0]

FinalTable
# Out:
#             ORB     BRISK      SURF Ours (512dim) Ours (1024dim)
# K5L5   0.753681  0.682999  0.712838       0.77068        0.78943
# K15L5  0.748066   0.74759  0.770941      0.773851       0.784822
# K10L5  0.751711  0.735806  0.763036      0.769743       0.782901
