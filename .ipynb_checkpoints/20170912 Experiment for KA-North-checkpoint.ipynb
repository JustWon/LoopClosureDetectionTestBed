# %% [markdown]
# # Intro.
# - KAIST all day Test Bed 결과 확인

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from itertools import cycle
import configparser
import scipy.io as sio

from sklearn import svm, datasets
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

TARGET_EVAL_DATASET = 'KAIST_All_Day(North)'

# %%
from glob import glob
images = glob('/media/dongwonshin/Ubuntu Data/Datasets/KAIST_All_Day/Synced_Data/%s/images/small_size/*.jpg' % TARGET_EVAL_DATASET)

GT_corr_mat = np.zeros((len(images), len(images)))
for i in range(0,len(images),4):
    for j in range(i,i+4):
        GT_corr_mat[i,j] = 1
    for j in range(i+1,i+4):
        GT_corr_mat[i+1,j] = 1
    for j in range(i+2,i+4):
        GT_corr_mat[i+2,j] = 1
    for j in range(i+3,i+4):
        GT_corr_mat[i+3,j] = 1
        
plt.figure(figsize=(10,10))
plt.imshow(GT_corr_mat, cmap = 'hot')
plt.show()

# %%
def PrecisionRecallCurve(GT_corr_mat, esti_corr_mat):

    precision, recall, _ = precision_recall_curve(GT_corr_mat.flatten(), esti_corr_mat.flatten())
    average_precision = average_precision_score(GT_corr_mat.flatten(), esti_corr_mat.flatten())


    # Plot Precision-Recall curve
    plt.clf()
    plt.plot(recall, precision, lw=2, color='navy', label='Precision-Recall curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall example: AUC={0:0.2f}'.format(average_precision))
    plt.legend(loc="lower left")
    plt.show()
    
    return precision, recall
    
    
def theLatestResult(path_pattern):
    result_dirs = sorted(glob(path_pattern))
    the_latest_result_path = result_dirs[-1]
    print(the_latest_result_path)
    corr_mat_path = the_latest_result_path + '/corr_matrix.txt'
    param_cfg_path = the_latest_result_path + '/parameters.cfg'
    
    config = configparser.ConfigParser()
    config.read(param_cfg_path)
    print(dict(config.items('General')))
    

    return corr_mat_path, param_cfg_path

def theSpecificResult(path):
    corr_mat_path = path + '/corr_matrix.txt'
    param_cfg_path = path + '/output_config.ini'
    
    config = configparser.ConfigParser()
    config.read(param_cfg_path)
    print(dict(config.items('Experiment_parameters')))
    
    return corr_mat_path, param_cfg_path, dict(config.items('Experiment_parameters'))

# %% [markdown]
# # K=10, L=5

# %%
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-11-07-53',
# '/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-10-50-39',
# '/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-10-49-29',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-10-10-12',
]

curve_results = []
for testcase in testcases:
    corr_mat, param_cfg, params = theSpecificResult(testcase)
    esti_corr_mat = np.loadtxt(corr_mat)
    if (params['eval_dataset'] == TARGET_EVAL_DATASET):
        curve_results.append([PrecisionRecallCurve(GT_corr_mat, esti_corr_mat), params])
    else:
        print(params)
        print('current eval dataset is not %s (which is the target)' % TARGET_EVAL_DATASET)
# Out:
# {'network_model': 'bigger_feature_size', 'depth_level': '5', 'exp_method': 'SURF', 'eval_desc': 'all_desc', 'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(North)', 'cluster_center': '10'}
# {'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(North)', 'cluster_center': '10', 'depth_level': '5', 'exp_method': 'orb'}
# /home/dongwonshin/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:11: UserWarning: loadtxt: Empty input file: "/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-10-50-39/corr_matrix.txt"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-dce7aa038226> in <module>()
#      11     esti_corr_mat = np.loadtxt(corr_mat)
#      12     if (params['eval_dataset'] == TARGET_EVAL_DATASET):
# ---> 13         curve_results.append([PrecisionRecallCurve(GT_corr_mat, esti_corr_mat), params])
#      14     else:
#      15         print(params)
#
# <ipython-input-10-ecba7bf50fb1> in PrecisionRecallCurve(GT_corr_mat, esti_corr_mat)
#       1 def PrecisionRecallCurve(GT_corr_mat, esti_corr_mat):
#       2
# ----> 3     precision, recall, _ = precision_recall_curve(GT_corr_mat.flatten(), esti_corr_mat.flatten())
#       4     average_precision = average_precision_score(GT_corr_mat.flatten(), esti_corr_mat.flatten())
#       5
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/sklearn/metrics/ranking.py in precision_recall_curve(y_true, probas_pred, pos_label, sample_weight)
#     415     fps, tps, thresholds = _binary_clf_curve(y_true, probas_pred,
#     416                                              pos_label=pos_label,
# --> 417                                              sample_weight=sample_weight)
#     418
#     419     precision = tps / (tps + fps)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/sklearn/metrics/ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     300         Decreasing score values.
#     301     """
# --> 302     check_consistent_length(y_true, y_score)
#     303     y_true = column_or_1d(y_true)
#     304     y_score = column_or_1d(y_score)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     171     if len(uniques) > 1:
#     172         raise ValueError("Found input variables with inconsistent numbers of"
# --> 173                          " samples: %r" % [int(l) for l in lengths])
#     174
#     175
#
# ValueError: Found input variables with inconsistent numbers of samples: [41616, 0]

# %%
# Plot Precision-Recall curve
plt.figure(figsize=(10,7))
plt.clf()
for curve, color in zip(curve_results, ['red','green','blue','black']):
    plt.plot(curve[0][1], curve[0][0], lw=2, color=color, label=curve[1]['exp_method'])

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve')
plt.legend(loc="lower left")
plt.show()
