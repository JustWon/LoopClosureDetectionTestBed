# %% [markdown]
# # Intro.
# - KAIST all day Test Bed 결과 확인

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from itertools import cycle
import configparser
import scipy.io as sio

from sklearn import svm, datasets
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

TARGET_EVAL_DATASET = 'KAIST_All_Day(West)'

# %%
from glob import glob
images = glob('/media/dongwonshin/Ubuntu Data/Datasets/KAIST_All_Day/Synced_Data/KAIST_All_Day(West)/images/small_size/*.jpg')

GT_corr_mat = np.zeros((len(images), len(images)))
for i in range(0,len(images),4):
    for j in range(i,i+4):
        GT_corr_mat[i,j] = 1
    for j in range(i+1,i+4):
        GT_corr_mat[i+1,j] = 1
    for j in range(i+2,i+4):
        GT_corr_mat[i+2,j] = 1
    for j in range(i+3,i+4):
        GT_corr_mat[i+3,j] = 1
        
plt.figure(figsize=(10,10))
plt.imshow(GT_corr_mat, cmap = 'hot')
plt.show()

# %%
def PrecisionRecallCurve(GT_corr_mat, esti_corr_mat):

    precision, recall, _ = precision_recall_curve(GT_corr_mat.flatten(), esti_corr_mat.flatten())
    average_precision = average_precision_score(GT_corr_mat.flatten(), esti_corr_mat.flatten())


    # Plot Precision-Recall curve
    plt.clf()
    plt.plot(recall, precision, lw=2, color='navy', label='Precision-Recall curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall example: AUC={0:0.2f}'.format(average_precision))
    plt.legend(loc="lower left")
    plt.show()
    
    return precision, recall
    
    
def theLatestResult(path_pattern):
    result_dirs = sorted(glob(path_pattern))
    the_latest_result_path = result_dirs[-1]
    print(the_latest_result_path)
    corr_mat_path = the_latest_result_path + '/corr_matrix.txt'
    param_cfg_path = the_latest_result_path + '/parameters.cfg'
    
    config = configparser.ConfigParser()
    config.read(param_cfg_path)
    print(dict(config.items('General')))
    

    return corr_mat_path, param_cfg_path

def theSpecificResult(path):
    corr_mat_path = path + '/corr_matrix.txt'
    param_cfg_path = path + '/output_config.ini'
    
    config = configparser.ConfigParser()
    config.read(param_cfg_path)
    print(dict(config.items('Experiment_parameters')))
    
    return corr_mat_path, param_cfg_path, dict(config.items('Experiment_parameters'))

# %% [markdown]
# # K=10, L=5

# %%
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-03-21-43',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-03-17-39',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-01-53-53',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-01-50-04',
]

curve_results = []
for testcase in testcases:
    corr_mat, param_cfg, params = theSpecificResult(testcase)
    esti_corr_mat = np.loadtxt(corr_mat)
    curve_results.append([PrecisionRecallCurve(GT_corr_mat, esti_corr_mat), params])
# Out:
# {'cluster_center': '10', 'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'depth_level': '5', 'exp_method': 'orb'}
# {'cluster_center': '10', 'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'depth_level': '5', 'exp_method': 'brisk'}
# {'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'cluster_center': '10', 'exp_method': 'proposed method', 'network_model': 'bigger_feature_size', 'depth_level': '5', 'eval_desc': 'all_desc'}
# {'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'cluster_center': '10', 'exp_method': 'SURF', 'network_model': 'bigger_feature_size', 'depth_level': '5', 'eval_desc': 'all_desc'}

# %%
# Plot Precision-Recall curve
plt.figure(figsize=(10,7))
plt.clf()
for curve, color in zip(curve_results, ['red','green','blue','black']):
    plt.plot(curve[0][1], curve[0][0], lw=2, color=color, label=curve[1]['exp_method'])

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve')
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# # K=5, L=5

# %%
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-15-58-55',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-15-54-30',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-14-48-11',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-14-45-18',
]

curve_results = []
for testcase in testcases:
    corr_mat, param_cfg, params = theSpecificResult(testcase)
    esti_corr_mat = np.loadtxt(corr_mat)
    if (params['eval_dataset'] == TARGET_EVAL_DATASET):
        curve_results.append([PrecisionRecallCurve(GT_corr_mat, esti_corr_mat), params])
    else:
        print(params)
        print('current eval dataset is not %s (which is the target)' % TARGET_EVAL_DATASET)
        
# Plot Precision-Recall curve
plt.figure(figsize=(10,7))
plt.clf()
for curve, color in zip(curve_results, ['red','green','blue','black']):
    plt.plot(curve[0][1], curve[0][0], lw=2, color=color, label=curve[1]['exp_method'])

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve')
plt.legend(loc="lower left")
plt.show()
# Out:
# {'cluster_center': '5', 'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'depth_level': '5', 'exp_method': 'orb'}
# {'cluster_center': '5', 'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'depth_level': '5', 'exp_method': 'brisk'}
# {'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'cluster_center': '5', 'exp_method': 'proposed method', 'network_model': 'bigger_feature_size', 'depth_level': '5', 'eval_desc': 'all_desc'}
# {'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'cluster_center': '5', 'exp_method': 'SURF', 'network_model': 'bigger_feature_size', 'depth_level': '5', 'eval_desc': 'all_desc'}

# %% [markdown]
# # K=15, L =5

# %%
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-19-11-09',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-19-03-38',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-16-17-58',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-09-12-16-10-09',
]

curve_results = []
for testcase in testcases:
    corr_mat, param_cfg, params = theSpecificResult(testcase)
    esti_corr_mat = np.loadtxt(corr_mat)
    if (params['eval_dataset'] == TARGET_EVAL_DATASET):
        curve_results.append([PrecisionRecallCurve(GT_corr_mat, esti_corr_mat), params])
    else:
        print(params)
        print('current eval dataset is not %s (which is the target)' % TARGET_EVAL_DATASET)
        
# Plot Precision-Recall curve
plt.figure(figsize=(10,7))
plt.clf()
for curve, color in zip(curve_results, ['red','green','blue','black']):
    plt.plot(curve[0][1], curve[0][0], lw=2, color=color, label=curve[1]['exp_method'])

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve')
plt.legend(loc="lower left")
plt.show()
# Out:
# {'cluster_center': '15', 'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'depth_level': '5', 'exp_method': 'orb'}
# {'cluster_center': '15', 'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'depth_level': '5', 'exp_method': 'brisk'}
# {'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'cluster_center': '15', 'exp_method': 'proposed method', 'network_model': 'bigger_feature_size', 'depth_level': '5', 'eval_desc': 'all_desc'}
# {'scoring_type': 'L1_NORM', 'eval_dataset': 'KAIST_All_Day(West)', 'cluster_center': '15', 'exp_method': 'SURF', 'network_model': 'bigger_feature_size', 'depth_level': '5', 'eval_desc': 'all_desc'}
