# %% [markdown]
# # Intro.
# - City centre, Survey final 데이터에 대한 평가
# - Exp_Util.py로 정리

# %%
# %matplotlib inline
from Exp_Util import *

ap_table = {}

# %%
dataset_name = 'CC'
GT_corr_mat = GT_corr_mat_viz(cc_real_corr_list)

# %% [markdown]
# # K=10, L=5

# %%
exp_dict = {
    'cluster_center' : 10,
    'depth_level' : 5
}
testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-42-19',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-39-47',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-30-27',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-17-55-21',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-20-54-46',
]

table = intraExpPlot(dataset_name, exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.791548  0.772833  0.835172        0.852243       0.835306

# %% [markdown]
# # K=15, L=5

# %%
exp_dict = {
    'cluster_center' : 15,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-56-17',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-51-10',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-45-48',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-58-07',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-21-02-50',
]
table = intraExpPlot(dataset_name, exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK      SURF  Ours (2048dim)  Ours (512dim)
# 0  0.787556  0.776612  0.839446        0.850707       0.829264

# %% [markdown]
# # K=5, L=5

# %%
exp_dict = {
    'cluster_center' : 5,
    'depth_level' : 5
}

testcases = [
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-56-41',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-54-42',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-20-49-44',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-02-21-26-08',
'/home/dongwonshin/Desktop/LoopClosureDetectionTestBed/result_folder/2017-10-06-20-59-43',
]

table = intraExpPlot(dataset_name, exp_dict, testcases, GT_corr_mat)
key = 'K%dL%d' % (exp_dict['cluster_center'], exp_dict['depth_level'])
ap_table[key] = table
# Out:
#         ORB     BRISK     SURF  Ours (2048dim)  Ours (512dim)
# 0  0.798278  0.714412  0.79865        0.848834       0.834998

# %%
column_order = ['ORB','BRISK','SURF','Ours (512dim)','Ours (1024dim)']
FinalTable = DataFrame(columns=column_order)
for k,v in zip(ap_table.keys(), ap_table.values()):
    for col in column_order:
        FinalTable.loc[k,col] = v[col].values[0]

FinalTable
# Out:
#             ORB     BRISK      SURF Ours (512dim) Ours (1024dim)
# K10L5  0.791548  0.772833  0.835172      0.835306       0.852243
# K15L5  0.787556  0.776612  0.839446      0.829264       0.850707
# K5L5   0.798278  0.714412   0.79865      0.834998       0.848834
